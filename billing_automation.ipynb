# %% [markdown]
# <a href="https://colab.research.google.com/github/ozzysp/automated_emails/blob/main/billing_automation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl (904kB)
#      |████████████████████████████████| 911kB 7.6MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from selenium) (1.24.3)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from selenium import webdriver
import time

clients_table = pd.read_excel('/content/drive/MyDrive/clients_automation/Clientes Pagamento.xlsx', dtype={'Cliente': object})
clients_table['Email'].replace('pythonimpressionador', 'eletricidadebolt', regex= True, inplace=True)
clients_table
# Out:
#         Cliente        Nome  ...  Valor Total Devido                          Email
# 0   11122233312        José  ...                8950   eletricidadebolt+1@gmail.com
# 1   11122233345       Maria  ...                8950   eletricidadebolt+2@gmail.com
# 2   11122233367        João  ...                8950   eletricidadebolt+3@gmail.com
# 3   22233344456     Antônio  ...                8950   eletricidadebolt+4@gmail.com
# 4   22233344484   Francisco  ...                8950   eletricidadebolt+5@gmail.com
# 5   25566677829      Carlos  ...                8950   eletricidadebolt+6@gmail.com
# 6   28900011174       Paulo  ...                8950   eletricidadebolt+7@gmail.com
# 7   32233344520       Pedro  ...                8950   eletricidadebolt+8@gmail.com
# 8   35566677865       Lucas  ...                8950   eletricidadebolt+9@gmail.com
# 9   38900011211        Luiz  ...                8950  eletricidadebolt+10@gmail.com
# 10  42233344556      Marcos  ...                8950  eletricidadebolt+11@gmail.com
# 11  45566677901        Luis  ...                8950  eletricidadebolt+12@gmail.com
# 12  48900011247     Gabriel  ...                8950  eletricidadebolt+13@gmail.com
# 13  52233344592      Rafael  ...                8950  eletricidadebolt+14@gmail.com
# 14  55566677938      Daniel  ...                8950  eletricidadebolt+15@gmail.com
# 15  58900011283     Marcelo  ...                8950  eletricidadebolt+16@gmail.com
# 16  62233344628       Bruno  ...                8950  eletricidadebolt+17@gmail.com
# 17  65566677974     Eduardo  ...                8950  eletricidadebolt+18@gmail.com
# 18  68900011319      Felipe  ...                8950  eletricidadebolt+19@gmail.com
# 19  72233344665    Raimundo  ...                8950  eletricidadebolt+20@gmail.com
# 20  75566678010     Rodrigo  ...                8950  eletricidadebolt+21@gmail.com
# 21  78900011355         Ana  ...                8950  eletricidadebolt+22@gmail.com
# 22  82233344701   Francisca  ...                8950  eletricidadebolt+23@gmail.com
# 23  85566678046     Antônia  ...                8950  eletricidadebolt+24@gmail.com
# 24  88900011392     Adriana  ...                8950  eletricidadebolt+25@gmail.com
# 25  92233344737     Juliana  ...                8950  eletricidadebolt+26@gmail.com
# 26  95566678082      Márcia  ...                8950  eletricidadebolt+27@gmail.com
# 27  98900011428    Fernanda  ...                8950  eletricidadebolt+28@gmail.com
# 28  02233344773    Patricia  ...                8950  eletricidadebolt+29@gmail.com
# 29  05566678119       Aline  ...                8950  eletricidadebolt+30@gmail.com
# 30  08900011464      Sandra  ...                8950  eletricidadebolt+31@gmail.com
# 31  12233344809      Camila  ...                8950  eletricidadebolt+32@gmail.com
# 32  15566678155      Amanda  ...                8950  eletricidadebolt+33@gmail.com
# 33  18900011500       Bruna  ...                8950  eletricidadebolt+34@gmail.com
# 34  22233344846     Jéssica  ...                8950  eletricidadebolt+35@gmail.com
# 35  25566678191     Leticia  ...                8950  eletricidadebolt+36@gmail.com
# 36  28900011536       Júlia  ...                8950  eletricidadebolt+37@gmail.com
# 37  32233344882     Luciana  ...                8950  eletricidadebolt+38@gmail.com
# 38  35566678227     Vanessa  ...                8950  eletricidadebolt+39@gmail.com
# 39  38900011573     Mariana  ...                8950  eletricidadebolt+40@gmail.com
# 40  42233344918      Amanda  ...                8950  eletricidadebolt+41@gmail.com
# 41  45566678263  Alessandra  ...                8950  eletricidadebolt+42@gmail.com
# 42  48900011609        Alon  ...                8950  eletricidadebolt+43@gmail.com
# 43  52233344954      Marlon  ...                8950  eletricidadebolt+44@gmail.com
# 44  55566678300       Diego  ...                8950  eletricidadebolt+45@gmail.com
# 45  58900011645        Enzo  ...                8950  eletricidadebolt+46@gmail.com
# 46  62233344990   Valentina  ...                8950  eletricidadebolt+47@gmail.com
# 47  65566678336        Rosa  ...                8950  eletricidadebolt+48@gmail.com
# 48  68900011681    Andressa  ...                8950  eletricidadebolt+49@gmail.com
#
# [49 rows x 5 columns]

# %% [markdown]
# **Payment platform**

# %%
driver = webdriver.Chrome()
driver.get('https://acesso.pagseguro.uol.com.br/')

driver.find_element_by_id('user').send_keys(email_pagseguro) 
driver.find_element_by_id('password').send_keys(password_pagseguro) 
time.sleep(5)
driver.find_element_by_xpath('//*[@id="__next"]/div/div/main/div/div/div/form/div/div/div/div/div[3]/button').click()

while len(driver.find_elements_by_id('menu'))==0:
    time.sleep(10)
    
for line in clients_table.index:
    divida = clients_table.loc[linha, 'Valor Total Devido'] - clients_table.loc[linha, 'Valor Pago']
    if divida > 0:
        driver.get('https://pagseguro.uol.com.br/operations/charging.jhtml')
        email = clientes_table.loc[linha, 'Email']
        driver.find_element_by_xpath('//*[@id="newRequestForm"]/div[1]/section[1]/div/fieldset[1]/input').send_keys(email)
        nome = clientes_table.loc[linha, 'Nome']
        driver.find_element_by_xpath('//*[@id="newRequestForm"]/div[1]/section[1]/div/fieldset[2]/input').send_keys(name)
        driver.find_element_by_xpath('//*[@id="newRequestForm"]/div[1]/section[2]/div/fieldset[1]/input').send_keys('Cobrança pagamento atrasado')

        value = debit
        text_value = f'{value:.2f}' 
        driver.find_element_by_xpath('//*[@id="newRequestForm"]/div[1]/section[2]/div/fieldset[2]/div/input').send_keys(text_value)
        driver.find_element_by_id('sendNewCharging').click()
        time.sleep(0.5)
        driver.find_element_by_id('buttonConfirmSubmit').click()
        time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/selenium/webdriver/common/service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# /usr/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# /usr/lib/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1550                             err_msg += ': ' + repr(err_filename)
# -> 1551                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1552                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'chromedriver': 'chromedriver'
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-6-42a1de8c338c> in <module>()
# ----> 1 driver = webdriver.Chrome()
#       2 driver.get('https://acesso.pagseguro.uol.com.br/')
#       3
#       4 driver.find_element_by_id('user').send_keys(email_pagseguro)
#       5 driver.find_element_by_id('password').send_keys(password_pagseguro)
#
# /usr/local/lib/python3.7/dist-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      71             service_args=service_args,
#      72             log_path=service_log_path)
# ---> 73         self.service.start()
#      74
#      75         try:
#
# /usr/local/lib/python3.7/dist-packages/selenium/webdriver/common/service.py in start(self)
#      81                 raise WebDriverException(
#      82                     "'%s' executable needs to be in PATH. %s" % (
# ---> 83                         os.path.basename(self.path), self.start_error_message)
#      84                 )
#      85             elif err.errno == errno.EACCES:
#
# WebDriverException: Message: 'chromedriver' executable needs to be in PATH. Please see https://sites.google.com/a/chromium.org/chromedriver/home
